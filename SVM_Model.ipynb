# %% [markdown]
# <a href="https://colab.research.google.com/github/krupa2002/ML_kdp/blob/main/SVM_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Support Vector Machine (SVM)

# %% [markdown]
# ### **Support Vector Machine**
#
# A Support Vector Machine (SVM) is a supervised learning algorithm used for classification and regression tasks. It works by finding the best boundary (hyperplane) that separates different classes in the data. SVM tries to maximize the margin between this boundary and the closest data points (support vectors) from each class. It can handle both linear and non-linear data by using kernel functions. SVMs are effective in high-dimensional spaces and are versatile in terms of classification complexity.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **3 Main reasons why we use SVM-**
#
# 1. **High-Dimensional Effectiveness:** Performs well with many features.
# 2. **Kernel Versatility:** Handles linear and non-linear data.
# 3. **Overfitting Robustness:** Focuses on critical points, reducing overfitting.

# %% [markdown]
# ### **When we should SVM**
#
# 1. **High-Dimensional Data:** When the number of features is large relative to the number of samples.
# 2. **Non-linear Boundaries:** When the decision boundary between classes is not linear.
# 3. **Small to Medium-Sized Datasets:** When dealing with datasets where overfitting is a concern but computational resources are limited.

# %% [markdown]
# ### **Hyperplane in SVM**
#
# 1. Hyperplane:
#
# A hyperplane is use to separate different classes of data.
# For a 2-dimensional space, this is a line, but in higher dimensions, it becomes a hyperplane.
# The goal is to find the hyperplane that maximizes the margin between the classes.
#
# 2. Maximizing the Margin:
#
# The SVM algorithm seeks the hyperplane that has the largest distance (margin) to the nearest points from any class, which are called support vectors.
# This maximized margin helps improve the generalization ability of the classifier.
#
# 3. Support Vectors:
#
# These are the data points that are closest to the hyperplane and influence its position and orientation.
# The hyperplane is defined based on these support vectors, rather than the entire dataset.

# %% [markdown]
# ### **Steps to implement Linear Regression**
#
# 1. **Data Preprocessing**: Prepare your dataset by cleaning, transforming, and scaling as necessary.
#
# 2. **Split Data**: Divide the dataset into training and testing sets for evaluation.
#
# 3. **Choose Kernel**: Select a kernel type (e.g., linear, polynomial, RBF) and tune its parameters if necessary.
#
# 4. **Instantiate SVM**: Create an SVM classifier object with chosen parameters and kernel.
#
# 5. **Train the Model**: Fit the SVM classifier to the training data.
#
# 6. **Predictions**: Use the trained SVM model to predict outcomes for new data.
#
# 7. **Evaluate Performance**: Assess the model's accuracy and other metrics using the test set.

# %% [markdown]
# ### **Evaluation Metrics in SVM**
#
# 1. **Accuracy**: The proportion of correctly classified instances out of the total instances evaluated.
#
# 2. **Precision**: The ratio of true positive predictions to the total predicted positives. It measures the accuracy of positive predictions.
#
# 3. **Recall (Sensitivity)**: The ratio of true positive predictions to the total actual positives. It measures the ability of the model to identify all positive instances.
#
# 4. **F1 Score**: The harmonic mean of precision and recall. It provides a single metric that balances both precision and recall.
#
# 5. **Confusion Matrix**: A table that summarizes the number of true positives, true negatives, false positives, and false negatives. It's useful for understanding where the model is making errors.
#
# 6. **ROC Curve (Receiver Operating Characteristic Curve)**: A graphical plot that illustrates the performance of a binary classifier as its discrimination threshold is varied. It plots the true positive rate (TPR) against the false positive rate (FPR).
#
# 7. **AUC (Area Under the ROC Curve)**: The area under the ROC curve. It provides an aggregate measure of performance across all possible classification thresholds.
#
# 8. **Precision-Recall Curve**: A graphical plot that shows the trade-off between precision and recall for different threshold values.

# %% [markdown]
# ### **Application of SVM**
#
# 1. **Image Classification and Object Recognition:**
#    SVMs excel in accurately categorizing images into predefined classes, making them valuable in applications like autonomous vehicles for identifying road signs and pedestrians.
#
# 2. **Biomedical Applications:**
#    In bioinformatics, SVMs are crucial for analyzing gene expression data and predicting protein function, aiding in disease diagnosis and drug discovery efforts.

# %% [markdown]
# ### **About Notebook and Dataset**
#
# Here's brief description of Breast Cancer dataset
#
# Sure, here's a brief description of each column in the provided dataset in 5 words:
#
# 1. **id:** Unique identification number.
# 2. **diagnosis:** Malignant (M) or benign (B).
# 3. **radius_mean:** Mean radius of tumor.
# 4. **texture_mean:** Mean texture of tumor.
# 5. **perimeter_mean:** Mean perimeter of tumor.
# 6. **area_mean:** Mean area of tumor.
# 7. **smoothness_mean:** Mean smoothness of tumor.
# 8. **compactness_mean:** Mean compactness of tumor.
# 9. **concavity_mean:** Mean concavity of tumor.
# 10. **concave points_mean:** Mean number of concave portions.
# 11. **symmetry_mean:** Mean symmetry of tumor.
# 12. **fractal_dimension_mean:** Mean fractal dimension of tumor.
# 13. **radius_se:** Standard error of radius.
# 14. **texture_se:** Standard error of texture.
# 15. **perimeter_se:** Standard error of perimeter.
# 16. **area_se:** Standard error of area.
# 17. **smoothness_se:** Standard error of smoothness.
# 18. **compactness_se:** Standard error of compactness.
# 19. **concavity_se:** Standard error of concavity.
# 20. **concave points_se:** Standard error of concave points.
# 21. **symmetry_se:** Standard error of symmetry.
# 22. **fractal_dimension_se:** Standard error of fractal dimension.
# 23. **radius_worst:** Worst (largest) radius of tumor.
# 24. **texture_worst:** Worst (largest) texture of tumor.
# 25. **perimeter_worst:** Worst (largest) perimeter of tumor.
# 26. **area_worst:** Worst (largest) area of tumor.
# 27. **smoothness_worst:** Worst (largest) smoothness of tumor.
# 28. **compactness_worst:** Worst (largest) compactness of tumor.
# 29. **concavity_worst:** Worst (largest) concavity of tumor.
# 30. **concave points_worst:** Worst (largest) number of concave portions.
# 31. **symmetry_worst:** Worst (largest) symmetry of tumor.
# 32. **fractal_dimension_worst:** Worst (largest) fractal dimension of tumor.
# 33. **Unnamed: 32:** Additional unspecified column (likely NaN values).
#
# Dataset Link -
#
# Notebook Link -
#
# The code we performed demonstrates building a SVM model using the given dataset. Here's a summary of the steps:
#
# 1. **Data Preparation:** Load, clean, and preprocess the dataset for analysis.
#
# 2. **Visualization:** Explore data distributions and correlations visually.
#
# 3. **Feature Selection:** Choose relevant features for the SVM model.
#
# 4. **Model Training:** Split data, scale features, and train the SVM model.
#
# 5. **Prediction:** Generate predictions on test data.
#
# 6. **Evaluation:** Assess model performance using metrics like confusion matrix and classification report.
#
# 7. **Visualization of Results:** Visualize model evaluation results.
#
# 8. **Conclusion:** Summarize findings and propose next steps for refinement or application.
#
# Overall, the code demonstrates a basic workflow for building and evaluating a SVM model using Python and scikit-learn.

# %% [markdown]
# # 1. EDA

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
pd = pd.read_csv('/content/data.csv')

# %%
pd
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
pd.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
pd.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
pd.shape
# Out:
# (569, 33)

# %%
pd.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
pd.nunique()
# Out:
# id                         569
# diagnosis                    2
# radius_mean                456
# texture_mean               479
# perimeter_mean             522
# area_mean                  539
# smoothness_mean            474
# compactness_mean           537
# concavity_mean             537
# concave points_mean        542
# symmetry_mean              432
# fractal_dimension_mean     499
# radius_se                  540
# texture_se                 519
# perimeter_se               533
# area_se                    528
# smoothness_se              547
# compactness_se             541
# concavity_se               533
# concave points_se          507
# symmetry_se                498
# fractal_dimension_se       545
# radius_worst               457
# texture_worst              511
# perimeter_worst            514
# area_worst                 544
# smoothness_worst           411
# compactness_worst          529
# concavity_worst            539
# concave points_worst       492
# ...

# %%
pd.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
(pd.isnull().sum()/(len(pd)))*100
# Out:
# id                           0.0
# diagnosis                    0.0
# radius_mean                  0.0
# texture_mean                 0.0
# perimeter_mean               0.0
# area_mean                    0.0
# smoothness_mean              0.0
# compactness_mean             0.0
# concavity_mean               0.0
# concave points_mean          0.0
# symmetry_mean                0.0
# fractal_dimension_mean       0.0
# radius_se                    0.0
# texture_se                   0.0
# perimeter_se                 0.0
# area_se                      0.0
# smoothness_se                0.0
# compactness_se               0.0
# concavity_se                 0.0
# concave points_se            0.0
# symmetry_se                  0.0
# fractal_dimension_se         0.0
# radius_worst                 0.0
# texture_worst                0.0
# perimeter_worst              0.0
# area_worst                   0.0
# smoothness_worst             0.0
# compactness_worst            0.0
# ...

# %%
pd['diagnosis'] = pd['diagnosis'].apply(lambda x: '1' if x == 'M' else '0')
pd = pd.set_index('id')
del pd['Unnamed: 32']

# %%
pd.head(5)
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           1        17.99         10.38          122.80     1001.0
# 842517           1        20.57         17.77          132.90     1326.0
# 84300903         1        19.69         21.25          130.00     1203.0
# 84348301         1        11.42         20.38           77.58      386.1
# 84358402         1        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  radius_worst  \
# id                                            ...
# ...

# %%
pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 569 entries, 842302 to 92751
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# # 2. Data Visualization

# %%
plt.figure(figsize=(8, 6))
sns.countplot(pd['diagnosis'])
plt.title('Distribution of Diagnoses')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()

# %%
sns.boxplot(x=pd["diagnosis"], y=pd["radius_mean"])
# Out:
# <Axes: xlabel='diagnosis', ylabel='radius_mean'>

# %%
pd.plot(kind='density', subplots=True, layout=(5,7), sharex=False, legend=False, fontsize=1)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 8))
sns.violinplot(x=pd['diagnosis'], y=pd['area_mean'], palette='Set2', inner='quartile')
plt.title('Violin Plot of Area Mean by Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Area Mean')
plt.show()
# Out:
# <ipython-input-33-7bda0c08f7cc>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=pd['diagnosis'], y=pd['area_mean'], palette='Set2', inner='quartile')

# %%
from matplotlib import cm as cm

fig = plt.figure()
ax1 = fig.add_subplot(111)
cmap = cm.get_cmap('jet', 30)
cax = ax1.imshow(pd.corr(), interpolation="none", cmap=cmap)
ax1.grid(True)
plt.title('Breast Cancer Attributes Correlation')

fig.colorbar(cax, ticks=[.15,.05,.005,.10,.18,0.004])
plt.show()
# Out:
# <ipython-input-34-55920bb3169a>:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('jet', 30)

# %% [markdown]
# # 3. Model Building

# %%
X = pd[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']]
y = pd['diagnosis']

# %%
print(pd.head())
print(pd.columns)
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           1        17.99         10.38          122.80     1001.0
# 842517           1        20.57         17.77          132.90     1326.0
# 84300903         1        19.69         21.25          130.00     1203.0
# 84348301         1        11.42         20.38           77.58      386.1
# 84358402         1        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  radius_worst  \
# id                                            ...
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Train an SVM model
svm = SVC(kernel='linear', C=1.0, random_state=42)
svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
y_pred = svm.predict(X_test)

# %% [markdown]
# # 4. Evaluation metrics

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[107   0]
#  [  6  58]]
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       107
#            1       1.00      0.91      0.95        64
#
#     accuracy                           0.96       171
#    macro avg       0.97      0.95      0.96       171
# weighted avg       0.97      0.96      0.96       171

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
