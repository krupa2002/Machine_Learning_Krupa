# %% [markdown]
# <a href="https://www.kaggle.com/code/krupadharamshi/kdp-ml-03?scriptVersionId=159870009" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **ML model**
# # **Linear Regression Model**

# %% [markdown]
# ## **Import library**

# %%
import pandas as pd

# %% [markdown]
# ## **Load data**

# %%
df = pd.read_csv("/kaggle/input/bostonhousing/BostonHousing.csv")

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# ## **Spliting dataset in X and Y variables**

# %%
Y = df.medv
Y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
X = df.drop(["medv"],axis = 1)
X
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %% [markdown]
# ## **Data split**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2)

# %%
X_train.shape, X_test.shape
# Out:
# ((404, 13), (102, 13))

# %%
Y_train.shape, Y_test.shape
# Out:
# ((404,), (102,))

# %% [markdown]
# ## **Linear Regression Model**

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### **Predicting results**

# %%
print("coefficent", model.coef_)
# Out:
# coefficent [-1.38213690e-01  5.51225647e-02  1.27529256e-02  2.87102221e+00
#  -1.88241966e+01  3.36463749e+00  6.59732881e-03 -1.40938196e+00
#   3.27609890e-01 -1.17410909e-02 -9.49923687e-01  8.68338454e-03
#  -5.34814890e-01]

# %%
print("intercept", model.intercept_)
# Out:
# intercept 39.05406769389782

# %%
print('mean squared error : % 2f'
       % mean_squared_error(Y_test,y_pred)
)
# Out:
# mean squared error :  22.726767

# %%
print('re score : % 2f'
       % r2_score(Y_test,y_pred))
# Out:
# re score :  0.761484

# %% [markdown]
# ## **String Formatting**
# Basically rounding off to 2 digit in r2 score because it is in float

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.7614840765735608

# %%
r2_score(Y_test,y_pred).dtype
# Out:
# dtype('float64')

# %%
'%f' % 0.785645345465768
# Out:
# '0.785645'

# %%
'%.3f' % 0.6545364564675768 #rounding off to 3 digit and same if we use 2f then rounding off to 2 digit
# Out:
# '0.655'

# %% [markdown]
# ## **Scatter plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(x = Y_test,y = y_pred)
# Out:
# <Axes: xlabel='medv'>

# %%
sns.scatterplot(x = Y_test,y = y_pred,marker = '+',color="red",alpha = 0.4)
# Out:
# <Axes: xlabel='medv'>
