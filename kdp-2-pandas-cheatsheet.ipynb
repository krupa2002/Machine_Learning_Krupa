# %% [markdown]
# **Table of content**
# 1. Importing pandas,reading dataset and saving it in dataframes.
# 2. Reading data using different types
# 3. Datatypes
# 4. Extracting columns by header types
# 5. Formatting data
# 6. Describing data
# 7. where(), nunique(), values_counts(), cut(), melt()
# 8. Categorical(), factorize(), aggregation(), dummies()
# 9. Period_range(), dropna(), to_date(), set_index(), round(), groupby(), crosstab(), pivot(), qcut()
# 10. Plotting

# %% [markdown]
# **1. Importing pandas,reading dataset and saving it in dataframes.**

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os

# %%
#Creating dataframe and storing datset in it
#here its fitness dataset
df= pd.read_csv("/kaggle/input/fitness-exercises-dataset/exercises.csv")
df
# Out:
#         bodyPart    equipment                                         gifUrl  \
# 0          waist  body weight  https://v2.exercisedb.io/image/MOnK4iG0MEt9h8
# 1          waist  body weight  https://v2.exercisedb.io/image/PERWLDGUxVbpHS
# 2          waist  body weight  https://v2.exercisedb.io/image/PLr4yo3j-f1amp
# 3     upper legs  body weight  https://v2.exercisedb.io/image/XPQwM7HECjgNFE
# 4          waist  body weight  https://v2.exercisedb.io/image/5nYph4eUGNiEdf
# ...          ...          ...                                            ...
# 1319       chest  body weight  https://v2.exercisedb.io/image/XQn4pU9HRquS2b
# 1320       waist  body weight  https://v2.exercisedb.io/image/ZLPKUAaiObH-2X
# 1321  upper legs  body weight  https://v2.exercisedb.io/image/3A5fPe5oCr2EwN
# 1322  lower arms  body weight  https://v2.exercisedb.io/image/o8lN2wxaJZIzlF
# 1323  lower arms     weighted  https://v2.exercisedb.io/image/bpHngD4xNKxD6u
#
# ...

# %%
#Creating dataframe and storing datset in it
#here its usa housing price dataset
df22 = pd.read_csv("/kaggle/input/usa-housing-listings/housing.csv")

# %%
#Creating dataframe and storing datset in it
#here its real time climate dataset
time1=pd.read_csv("/kaggle/input/daily-climate-time-series-data/DailyDelhiClimateTest.csv")
time1
# Out:
#            date   meantemp   humidity  wind_speed  meanpressure
# 0    2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1    2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2    2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3    2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4    2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ..          ...        ...        ...         ...           ...
# 109  2017-04-20  34.500000  27.500000    5.562500    998.625000
# 110  2017-04-21  34.250000  39.375000    6.962500    999.875000
# 111  2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 112  2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 113  2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]

# %%
#Creating dataframe and storing datset in it
#here its real time climate dataset
time2=pd.read_csv("/kaggle/input/daily-climate-time-series-data/DailyDelhiClimateTrain.csv")
time2
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %% [markdown]
# **2. Reading data using different types**

# %%
#reading data
df22.head()
# Out:
#            id                                                url  \
# 0  7049044568  https://reno.craigslist.org/apa/d/reno-beautif...
# 1  7049047186  https://reno.craigslist.org/apa/d/reno-reduced...
# 2  7043634882  https://reno.craigslist.org/apa/d/sparks-state...
# 3  7049045324  https://reno.craigslist.org/apa/d/reno-1x1-fir...
# 4  7049043759  https://reno.craigslist.org/apa/d/reno-no-long...
#
#          region                   region_url  price       type  sqfeet  beds  \
# 0  reno / tahoe  https://reno.craigslist.org   1148  apartment    1078     3
# 1  reno / tahoe  https://reno.craigslist.org   1200      condo    1001     2
# 2  reno / tahoe  https://reno.craigslist.org   1813  apartment    1683     2
# 3  reno / tahoe  https://reno.craigslist.org   1095  apartment     708     1
# 4  reno / tahoe  https://reno.craigslist.org    289  apartment     250     0
#
#    baths  cats_allowed  ...  wheelchair_access  electric_vehicle_charge  \
# ...

# %%
#reading data
df.head()
# Out:
#      bodyPart    equipment                                         gifUrl  \
# 0       waist  body weight  https://v2.exercisedb.io/image/MOnK4iG0MEt9h8
# 1       waist  body weight  https://v2.exercisedb.io/image/PERWLDGUxVbpHS
# 2       waist  body weight  https://v2.exercisedb.io/image/PLr4yo3j-f1amp
# 3  upper legs  body weight  https://v2.exercisedb.io/image/XPQwM7HECjgNFE
# 4       waist  body weight  https://v2.exercisedb.io/image/5nYph4eUGNiEdf
#
#      id                     name target secondaryMuscles/0 secondaryMuscles/1  \
# 0     1               3/4 sit-up    abs        hip flexors         lower back
# 1     2            45° side bend    abs           obliques                NaN
# 2     3                 air bike    abs        hip flexors                NaN
# 3  1512  all fours squad stretch  quads         hamstrings             glutes
# 4     6  alternate heel touchers    abs           obliques                NaN
#
# ...

# %%
#reading data
df.tail()
# Out:
#         bodyPart    equipment                                         gifUrl  \
# 1319       chest  body weight  https://v2.exercisedb.io/image/XQn4pU9HRquS2b
# 1320       waist  body weight  https://v2.exercisedb.io/image/ZLPKUAaiObH-2X
# 1321  upper legs  body weight  https://v2.exercisedb.io/image/3A5fPe5oCr2EwN
# 1322  lower arms  body weight  https://v2.exercisedb.io/image/o8lN2wxaJZIzlF
# 1323  lower arms     weighted  https://v2.exercisedb.io/image/bpHngD4xNKxD6u
#
#         id                                       name      target  \
# 1319  2363  wide-grip chest dip on high parallel bars   pectorals
# 1320   858                               wind sprints         abs
# 1321  1604                     world greatest stretch  hamstrings
# 1322  1428                              wrist circles    forearms
# 1323   859                             wrist rollerer    forearms
#
#      secondaryMuscles/0 secondaryMuscles/1  \
# 1319            triceps          shoulders
# ...

# %% [markdown]
# **3.Datatypes**

# %%
#column data types
df.dtypes
# Out:
# bodyPart              object
# equipment             object
# gifUrl                object
# id                     int64
# name                  object
# target                object
# secondaryMuscles/0    object
# secondaryMuscles/1    object
# instructions/0        object
# instructions/1        object
# instructions/2        object
# instructions/3        object
# instructions/4        object
# instructions/5        object
# secondaryMuscles/2    object
# instructions/6        object
# instructions/7        object
# secondaryMuscles/3    object
# instructions/8        object
# secondaryMuscles/4    object
# instructions/9        object
# secondaryMuscles/5    object
# instructions/10       object
# dtype: object

# %% [markdown]
# **4. Extracting columns by header types**

# %%
#Select object columns.
df.select_dtypes(object)
# Out:
#         bodyPart    equipment                                         gifUrl  \
# 0          waist  body weight  https://v2.exercisedb.io/image/MOnK4iG0MEt9h8
# 1          waist  body weight  https://v2.exercisedb.io/image/PERWLDGUxVbpHS
# 2          waist  body weight  https://v2.exercisedb.io/image/PLr4yo3j-f1amp
# 3     upper legs  body weight  https://v2.exercisedb.io/image/XPQwM7HECjgNFE
# 4          waist  body weight  https://v2.exercisedb.io/image/5nYph4eUGNiEdf
# ...          ...          ...                                            ...
# 1319       chest  body weight  https://v2.exercisedb.io/image/XQn4pU9HRquS2b
# 1320       waist  body weight  https://v2.exercisedb.io/image/ZLPKUAaiObH-2X
# 1321  upper legs  body weight  https://v2.exercisedb.io/image/3A5fPe5oCr2EwN
# 1322  lower arms  body weight  https://v2.exercisedb.io/image/o8lN2wxaJZIzlF
# 1323  lower arms     weighted  https://v2.exercisedb.io/image/bpHngD4xNKxD6u
#
# ...

# %%
#Select integer columns.
df.select_dtypes('int64')
# Out:
#         id
# 0        1
# 1        2
# 2        3
# 3     1512
# 4        6
# ...    ...
# 1319  2363
# 1320   858
# 1321  1604
# 1322  1428
# 1323   859
#
# [1324 rows x 1 columns]

# %%
#Format categorical columns.
f"Categorical columns{df.select_dtypes('object').columns.tolist()}"
# Out:
# "Categorical columns['bodyPart', 'equipment', 'gifUrl', 'name', 'target', 'secondaryMuscles/0', 'secondaryMuscles/1', 'instructions/0', 'instructions/1', 'instructions/2', 'instructions/3', 'instructions/4', 'instructions/5', 'secondaryMuscles/2', 'instructions/6', 'instructions/7', 'secondaryMuscles/3', 'instructions/8', 'secondaryMuscles/4', 'instructions/9', 'secondaryMuscles/5', 'instructions/10']"

# %%
#Format numerical columns.
f"Numerical columns{df.select_dtypes('int64').columns.tolist()}"
# Out:
# "Numerical columns['id']"

# %%
#Display integer columns.
df.select_dtypes('int64').head()
# Out:
#      id
# 0     1
# 1     2
# 2     3
# 3  1512
# 4     6

# %%
#Display object columns.
df.select_dtypes('object').head()
# Out:
#      bodyPart    equipment                                         gifUrl  \
# 0       waist  body weight  https://v2.exercisedb.io/image/MOnK4iG0MEt9h8
# 1       waist  body weight  https://v2.exercisedb.io/image/PERWLDGUxVbpHS
# 2       waist  body weight  https://v2.exercisedb.io/image/PLr4yo3j-f1amp
# 3  upper legs  body weight  https://v2.exercisedb.io/image/XPQwM7HECjgNFE
# 4       waist  body weight  https://v2.exercisedb.io/image/5nYph4eUGNiEdf
#
#                       name target secondaryMuscles/0 secondaryMuscles/1  \
# 0               3/4 sit-up    abs        hip flexors         lower back
# 1            45° side bend    abs           obliques                NaN
# 2                 air bike    abs        hip flexors                NaN
# 3  all fours squad stretch  quads         hamstrings             glutes
# 4  alternate heel touchers    abs           obliques                NaN
#
#                                       instructions/0  \
# ...

# %% [markdown]
# **5.Formatting data**

# %%
#Style integer columns.
df.select_dtypes('int64').head(5).style.background_gradient(cmap="OrRd")
# Out:
# <style type="text/css">
# #T_b4164_row0_col0, #T_b4164_row1_col0, #T_b4164_row2_col0, #T_b4164_row4_col0 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_b4164_row3_col0 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b4164">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4164_level0_col0" class="col_heading level0 col0" >id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4164_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4164_row0_col0" class="data row0 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b4164_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b4164_row1_col0" class="data row1 col0" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b4164_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b4164_row2_col0" class="data row2 col0" >3</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# **6.Describing data**

# %%
#List DataFrame columns.
df.columns
# Out:
# Index(['bodyPart', 'equipment', 'gifUrl', 'id', 'name', 'target',
#        'secondaryMuscles/0', 'secondaryMuscles/1', 'instructions/0',
#        'instructions/1', 'instructions/2', 'instructions/3', 'instructions/4',
#        'instructions/5', 'secondaryMuscles/2', 'instructions/6',
#        'instructions/7', 'secondaryMuscles/3', 'instructions/8',
#        'secondaryMuscles/4', 'instructions/9', 'secondaryMuscles/5',
#        'instructions/10'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1324, step=1)

# %%
#Display DataFrame index.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1324 entries, 0 to 1323
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bodyPart            1324 non-null   object
#  1   equipment           1324 non-null   object
#  2   gifUrl              1324 non-null   object
#  3   id                  1324 non-null   int64
#  4   name                1324 non-null   object
#  5   target              1324 non-null   object
#  6   secondaryMuscles/0  1324 non-null   object
#  7   secondaryMuscles/1  986 non-null    object
#  8   instructions/0      1324 non-null   object
#  9   instructions/1      1324 non-null   object
#  10  instructions/2      1324 non-null   object
#  11  instructions/3      1324 non-null   object
#  12  instructions/4      1242 non-null   object
#  13  instructions/5      739 non-null    object
#  14  secondaryMuscles/2  233 non-null    object
# ...

# %%
#Statistical summary display.
df.describe()
# Out:
#                 id
# count  1324.000000
# mean   1188.929003
# std    1007.723286
# min       1.000000
# 25%     377.750000
# 50%     860.500000
# 75%    1662.250000
# max    5201.000000

# %%
#Count non-null values.
df.count()
# Out:
# bodyPart              1324
# equipment             1324
# gifUrl                1324
# id                    1324
# name                  1324
# target                1324
# secondaryMuscles/0    1324
# secondaryMuscles/1     986
# instructions/0        1324
# instructions/1        1324
# instructions/2        1324
# instructions/3        1324
# instructions/4        1242
# instructions/5         739
# secondaryMuscles/2     233
# instructions/6         313
# instructions/7          92
# secondaryMuscles/3      32
# instructions/8          20
# secondaryMuscles/4       4
# instructions/9           5
# secondaryMuscles/5       2
# instructions/10          3
# dtype: int64

# %% [markdown]
# **7.where(), nunique(), values_counts(), cut(), melt()**

# %%
#Replace 'id' values with NaN where they are greater than or equal to 33.
import numpy as np
df['id'] = df['id'].where(df['id'] < 33, np.nan)
df
# Out:
#         bodyPart    equipment                                         gifUrl  \
# 0          waist  body weight  https://v2.exercisedb.io/image/MOnK4iG0MEt9h8
# 1          waist  body weight  https://v2.exercisedb.io/image/PERWLDGUxVbpHS
# 2          waist  body weight  https://v2.exercisedb.io/image/PLr4yo3j-f1amp
# 3     upper legs  body weight  https://v2.exercisedb.io/image/XPQwM7HECjgNFE
# 4          waist  body weight  https://v2.exercisedb.io/image/5nYph4eUGNiEdf
# ...          ...          ...                                            ...
# 1319       chest  body weight  https://v2.exercisedb.io/image/XQn4pU9HRquS2b
# 1320       waist  body weight  https://v2.exercisedb.io/image/ZLPKUAaiObH-2X
# 1321  upper legs  body weight  https://v2.exercisedb.io/image/3A5fPe5oCr2EwN
# 1322  lower arms  body weight  https://v2.exercisedb.io/image/o8lN2wxaJZIzlF
# 1323  lower arms     weighted  https://v2.exercisedb.io/image/bpHngD4xNKxD6u
#
# ...

# %%
#counting unique items 
unique_counts = df.nunique()
print(unique_counts)
# Out:
# bodyPart                10
# equipment               28
# gifUrl                1324
# id                      28
# name                  1318
# target                  19
# secondaryMuscles/0      29
# secondaryMuscles/1      35
# instructions/0         805
# instructions/1         985
# instructions/2        1078
# instructions/3         898
# instructions/4         604
# instructions/5         294
# secondaryMuscles/2      15
# instructions/6         106
# instructions/7          32
# secondaryMuscles/3       7
# instructions/8          10
# secondaryMuscles/4       2
# instructions/9           4
# secondaryMuscles/5       1
# instructions/10          3
# dtype: int64

# %%
#counting values counts
value_counts=df["name"].value_counts()
value_counts
# Out:
# name
# smith reverse calf raises          2
# barbell seated calf raise          2
# ez barbell spider curl             2
# push-up (on stability ball)        2
# lever chest press                  2
#                                   ..
# clock push-up                      1
# clap push up                       1
# circles knee stretch               1
# chin-ups (narrow parallel grip)    1
# wrist rollerer                     1
# Name: count, Length: 1318, dtype: int64

# %%
#Bin 'id' values into specified bins using pd.cut() with bin edges [1,2,3,4,5,6].
bin_edges = [1,2,3,4,5,6]
df['id']=pd.cut(df['id'],bins= bin_edges)
df
# Out:
#         bodyPart    equipment                                         gifUrl  \
# 0          waist  body weight  https://v2.exercisedb.io/image/MOnK4iG0MEt9h8
# 1          waist  body weight  https://v2.exercisedb.io/image/PERWLDGUxVbpHS
# 2          waist  body weight  https://v2.exercisedb.io/image/PLr4yo3j-f1amp
# 3     upper legs  body weight  https://v2.exercisedb.io/image/XPQwM7HECjgNFE
# 4          waist  body weight  https://v2.exercisedb.io/image/5nYph4eUGNiEdf
# ...          ...          ...                                            ...
# 1319       chest  body weight  https://v2.exercisedb.io/image/XQn4pU9HRquS2b
# 1320       waist  body weight  https://v2.exercisedb.io/image/ZLPKUAaiObH-2X
# 1321  upper legs  body weight  https://v2.exercisedb.io/image/3A5fPe5oCr2EwN
# 1322  lower arms  body weight  https://v2.exercisedb.io/image/o8lN2wxaJZIzlF
# 1323  lower arms     weighted  https://v2.exercisedb.io/image/bpHngD4xNKxD6u
#
# ...

# %%
#Melt DataFrame, unpivoting 'target' column, creating 'total' for variable names, and 'bodyParts' for values.
import pandas as pd

melted_df = df.melt(id_vars='target', var_name='total', value_name='bodyParts')

melted_df
# Out:
#            target            total   bodyParts
# 0             abs         bodyPart       waist
# 1             abs         bodyPart       waist
# 2             abs         bodyPart       waist
# 3           quads         bodyPart  upper legs
# 4             abs         bodyPart       waist
# ...           ...              ...         ...
# 29123   pectorals  instructions/10         NaN
# 29124         abs  instructions/10         NaN
# 29125  hamstrings  instructions/10         NaN
# 29126    forearms  instructions/10         NaN
# 29127    forearms  instructions/10         NaN
#
# [29128 rows x 3 columns]

# %% [markdown]
# **8. Categorical(), factorize(), aggregation(), dummies()**

# %%
#Create pandas Categorical.
cato = pd.Categorical(df)
cato
# Out:
# ['bodyPart', 'equipment', 'gifUrl', 'id', 'name', ..., 'instructions/8', 'secondaryMuscles/4', 'instructions/9', 'secondaryMuscles/5', 'instructions/10']
# Length: 23
# Categories (23, object): ['bodyPart', 'equipment', 'gifUrl', 'id', ..., 'secondaryMuscles/3', 'secondaryMuscles/4', 'secondaryMuscles/5', 'target']

# %%
#Factorize column 'name'.
labels, categories = pd.factorize(df['name'])
print(labels)
print(categories)
# Out:
# [   0    1    2 ... 1315 1316 1317]
# Index(['3/4 sit-up', '45° side bend', 'air bike', 'all fours squad stretch',
#        'alternate heel touchers', 'alternate lateral pulldown',
#        'ankle circles', 'archer pull up', 'archer push up',
#        'arm slingers hanging bent knee legs',
#        ...
#        'wheel rollerout', 'wheel run', 'wide grip pull-up',
#        'wide grip rear pull-up', 'wide hand push up',
#        'wide-grip chest dip on high parallel bars', 'wind sprints',
#        'world greatest stretch', 'wrist circles', 'wrist rollerer'],
#       dtype='object', length=1318)

# %%
#Aggregate ID min/max.
summary_stats=df.agg({'id':['min','max']})
summary_stats
# Out:
#          id
# min  (1, 2]
# max  (5, 6]

# %%
#Create name dummies.
dummy=pd.get_dummies(df['name'])
dummy
# Out:
#       3/4 sit-up  45° side bend  air bike  all fours squad stretch  \
# 0           True          False     False                    False
# 1          False           True     False                    False
# 2          False          False      True                    False
# 3          False          False     False                     True
# 4          False          False     False                    False
# ...          ...            ...       ...                      ...
# 1319       False          False     False                    False
# 1320       False          False     False                    False
# 1321       False          False     False                    False
# 1322       False          False     False                    False
# 1323       False          False     False                    False
#
#       alternate heel touchers  alternate lateral pulldown  ankle circles  \
# 0                       False                       False          False
# ...

# %% [markdown]
# **9.Period_range(), dropna(), to_date(), set_index(), round(), groupby(), crosstab(), pivot(), qcut()**

# %%
#Generate yearly periods.
periodrange = pd.period_range(start="22-04-2023", end="22-06-2024",freq="Y")
periodrange
# Out:
# PeriodIndex(['2023', '2024'], dtype='period[A-DEC]')

# %%
#Remove missing values.
df1=df.dropna()
df1
# Out:
# Empty DataFrame
# Columns: [bodyPart, equipment, gifUrl, id, name, target, secondaryMuscles/0, secondaryMuscles/1, instructions/0, instructions/1, instructions/2, instructions/3, instructions/4, instructions/5, secondaryMuscles/2, instructions/6, instructions/7, secondaryMuscles/3, instructions/8, secondaryMuscles/4, instructions/9, secondaryMuscles/5, instructions/10]
# Index: []
#
# [0 rows x 23 columns]

# %%
#Round to two.
df22.round(2)
# Out:
#                 id                                                url  \
# 0       7049044568  https://reno.craigslist.org/apa/d/reno-beautif...
# 1       7049047186  https://reno.craigslist.org/apa/d/reno-reduced...
# 2       7043634882  https://reno.craigslist.org/apa/d/sparks-state...
# 3       7049045324  https://reno.craigslist.org/apa/d/reno-1x1-fir...
# 4       7049043759  https://reno.craigslist.org/apa/d/reno-no-long...
# ...            ...                                                ...
# 384972  7049053337  https://reno.craigslist.org/apa/d/reno-2x2-thi...
# 384973  7049052968  https://reno.craigslist.org/apa/d/sparks-over-...
# 384974  7049050454  https://reno.craigslist.org/apa/d/sparks-1mont...
# 384975  7049050149  https://reno.craigslist.org/apa/d/sparks-ready...
# 384976  7049050010  https://reno.craigslist.org/apa/d/reno-2x2-thi...
#
#               region                   region_url  price       type  sqfeet  \
# ...

# %%
#read data
time1.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1  2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2  2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3  2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4  2017-01-05  18.388889  74.944444    3.300000   1014.333333

# %%
#Convert to datetime.
time1['date'] = pd.to_datetime(time1['date'])

# %%
#Set 'date' as index.
time1_dt = time1.set_index('date')
time1_dt
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2017-01-01  15.913043  85.869565    2.743478     59.000000
# 2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ...               ...        ...         ...           ...
# 2017-04-20  34.500000  27.500000    5.562500    998.625000
# 2017-04-21  34.250000  39.375000    6.962500    999.875000
# 2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 4 columns]

# %%
#Access index values.
time1_dt.index
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2017-04-15', '2017-04-16', '2017-04-17', '2017-04-18',
#                '2017-04-19', '2017-04-20', '2017-04-21', '2017-04-22',
#                '2017-04-23', '2017-04-24'],
#               dtype='datetime64[ns]', name='date', length=114, freq=None)

# %%
#Round index seconds.
time1_dt.index.round('S')
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10',
#                ...
#                '2017-04-15', '2017-04-16', '2017-04-17', '2017-04-18',
#                '2017-04-19', '2017-04-20', '2017-04-21', '2017-04-22',
#                '2017-04-23', '2017-04-24'],
#               dtype='datetime64[ns]', name='date', length=114, freq=None)

# %%
#Display first rows.
time1.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure
# 0 2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1 2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2 2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3 2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4 2017-01-05  18.388889  74.944444    3.300000   1014.333333

# %%
#Compute group mean. groupby() function
time1['GroupMean'] = time1.groupby('meantemp')['wind_speed'].transform('mean')

time1
# Out:
#           date   meantemp   humidity  wind_speed  meanpressure  GroupMean
# 0   2017-01-01  15.913043  85.869565    2.743478     59.000000   2.743478
# 1   2017-01-02  18.500000  77.222222    2.894444   1018.277778   2.894444
# 2   2017-01-03  17.111111  81.888889    4.016667   1018.333333   4.016667
# 3   2017-01-04  18.700000  70.050000    4.545000   1015.700000   7.182500
# 4   2017-01-05  18.388889  74.944444    3.300000   1014.333333   3.300000
# ..         ...        ...        ...         ...           ...        ...
# 109 2017-04-20  34.500000  27.500000    5.562500    998.625000   5.562500
# 110 2017-04-21  34.250000  39.375000    6.962500    999.875000   6.962500
# 111 2017-04-22  32.900000  40.900000    8.890000   1001.600000   8.890000
# 112 2017-04-23  32.875000  27.500000    9.962500   1002.125000   9.962500
# 113 2017-04-24  32.000000  27.142857   12.157143   1004.142857  12.157143
#
# [114 rows x 6 columns]

# %%
#Display cross-tabulation results.
cross_tab = pd.crosstab(time1['meantemp'], time1['humidity'])
cross_tab.head(7)
# Out:
# humidity   17.750000  19.428571  21.125000  24.125000  26.000000  27.142857  \
# meantemp
# 11.000000          0          0          0          0          0          0
# 11.722222          0          0          0          0          0          0
# 11.789474          0          0          0          0          0          0
# 12.111111          0          0          0          0          0          0
# 13.041667          0          0          0          0          0          0
# 13.200000          0          0          0          0          0          0
# 13.235294          0          0          0          0          0          0
#
# humidity   27.333333  27.500000  29.111111  29.375000  ...  79.318182  \
# meantemp                                               ...
# 11.000000          0          0          0          0  ...          0
# 11.722222          0          0          0          0  ...          0
# 11.789474          0          0          0          0  ...          0
# ...

# %%
#Create humidity pivot.
pivot_df = pd.pivot_table(time1, values='humidity', index='date', columns='meantemp', aggfunc='mean')
pivot_df
# Out:
# meantemp    11.000000  11.722222  11.789474  12.111111  13.041667  13.200000  \
# date
# 2017-01-01        NaN        NaN        NaN        NaN        NaN        NaN
# 2017-01-02        NaN        NaN        NaN        NaN        NaN        NaN
# 2017-01-03        NaN        NaN        NaN        NaN        NaN        NaN
# 2017-01-04        NaN        NaN        NaN        NaN        NaN        NaN
# 2017-01-05        NaN        NaN        NaN        NaN        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2017-04-20        NaN        NaN        NaN        NaN        NaN        NaN
# 2017-04-21        NaN        NaN        NaN        NaN        NaN        NaN
# 2017-04-22        NaN        NaN        NaN        NaN        NaN        NaN
# 2017-04-23        NaN        NaN        NaN        NaN        NaN        NaN
# 2017-04-24        NaN        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
#Quantile-based categorization.
categories = pd.qcut(time1["humidity"], q=7)
categories
# Out:
# 0      (77.508, 95.833]
# 1      (70.282, 77.508]
# 2      (77.508, 95.833]
# 3      (65.029, 70.282]
# 4      (70.282, 77.508]
#              ...
# 109    (17.749, 33.821]
# 110    (33.821, 41.321]
# 111    (33.821, 41.321]
# 112    (17.749, 33.821]
# 113    (17.749, 33.821]
# Name: humidity, Length: 114, dtype: category
# Categories (7, interval[float64, right]): [(17.749, 33.821] < (33.821, 41.321] < (41.321, 52.47] < (52.47, 65.029] < (65.029, 70.282] < (70.282, 77.508] < (77.508, 95.833]]

# %% [markdown]
# **10.Plotting**

# %%
#Plot time series.
time1.plot()
# Out:
# <Axes: >

# %%
#Plot time series with specific column
time1["date"].plot()
# Out:
# <Axes: >

# %%
#plot histogram
time1.hist(figsize=(20,20), bins=10)
# Out:
# array([[<Axes: title={'center': 'date'}>,
#         <Axes: title={'center': 'meantemp'}>],
#        [<Axes: title={'center': 'humidity'}>,
#         <Axes: title={'center': 'wind_speed'}>],
#        [<Axes: title={'center': 'meanpressure'}>,
#         <Axes: title={'center': 'GroupMean'}>]], dtype=object)

# %%
import pandas as pd
import numpy as np

# Creating a DataFrame with humidity and range data
data = {'humidity': np.random.randint(40, 60, size=10),
        '2017-01-01': np.random.randint(1, 5, size=10),
        '2017-01-08': np.random.randint(1, 5, size=10)}

time1 = pd.DataFrame(data)

# Adding error bars to the bar plot
ax = time1.plot.bar(y='humidity', yerr=[time1['2017-01-01'], time1['2017-01-08']], capsize=5, rot=0)

# Setting plot labels and title
ax.set_title('Humidity with Error Bars')
ax.set_xlabel('Data Points')
ax.set_ylabel('Humidity')
# Out:
# Text(0, 0.5, 'Humidity')
